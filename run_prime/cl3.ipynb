# %%
using Pkg
Pkg.activate(".")
# using Prime
# Out:
#   Activating project at `/home/mDisk/Prime-2`

# %%
using Distributed
addprocs(60)
@everywhere using Prime

# %%
using HDF5,DelimitedFiles,StatsBase
#Calculate cell-volume factor β
f = h5open("dataset/real_data/cl3_1137all.loom", "r")
X = read(f["layers/spliced"])+read(f["layers/unspliced"])
total_rd=sum(X,dims=2)
β = total_rd./mean(total_rd)

rdm = Matrix(readdlm("dataset/real_data/spliced_expression_matrix_3cl.csv",',')[2:end,2:end]')
rdn = Matrix(readdlm("dataset/real_data/unspliced_expression_matrix_3cl.csv", ',')[2:end,2:end]')

#cell number and gene number
n,p = size(rdm)
#Define cluster number and select model
k = 3
sel = 4
# Out:
# 4

# %%
cluster_labels, γ = Prime.prime_cluster(
    rdn, rdm, β, k;
    sel = sel,
    maxiter = 20,  
)
# Out:
# ┌ Info: PRIME iter 1, obj = 7.69027081677511
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 2, obj = 7.384852066488557
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 3, obj = 6.7028664175350485
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 4, obj = 5.856833573460902
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 5, obj = 5.13878456224586
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 6, obj = 4.783301108869544
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 7, obj = 4.558964495630953
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 8, obj = 4.415373705960178
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 9, obj = 4.322714723834206
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 10, obj = 4.2624523768227665
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 11, obj = 4.2221720395648035
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 12, obj = 4.222531425626877
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 13, obj = 4.222170053180971
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 14, obj = 4.222171350177069
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 15, obj = 4.22217531399769
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 16, obj = 4.222173047424585
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 17, obj = 4.222174600881514
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 18, obj = 4.222174565020392
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 19, obj = 4.222174565020392
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ┌ Info: PRIME iter 20, obj = 4.222174565020392
# └ @ Prime /home/mDisk/Prime-2/src/cluster.jl:120
# ([1, 1, 1, 1, 1, 3, 1, 1, 1, 1  …  3, 3, 1, 2, 1, 3, 3, 2, 1, 1], [1.0192342579608729 6.619190000320957e-41 4.21578371606702e-30; 1.0192342579608726 1.2575126379853095e-36 3.2496118862604496e-18; … ; 1.019234257960874 3.806731631964373e-46 1.5871281304589514e-40; 1.019234257960874 2.668616234252719e-36 5.9891304171872225e-28])

# %%
using Clustering
cell_type = readdlm("dataset/real_data/subclass_labels_3cl.csv",',')[2:end,2]
vec_numeric = replace(cell_type, "HCC827" => 1, "H1975" => 2, "H2228" => 3)

println("ARI for PRIME clustering:",randindex(Int.(cluster_labels),Int.(vec_numeric))[1])
println("NMI for PRIME clustering:",mutualinfo(Int.(cluster_labels),Int.(vec_numeric)))
# Out:
# ARI for PRIME clustering:0.9967518287529774
# NMI for PRIME clustering:0.9932464265926385
